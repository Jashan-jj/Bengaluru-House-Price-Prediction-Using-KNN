# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Bengaluru_House_Data.csv')
df.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00
# 5  DuenaTa       1170   2.0      1.0   38.00
# 6  Jaades        2732   4.0      NaN  204.00
# 7  Brway G       3300   4.0      NaN  600.00
# 8      NaN       1310   3.0      1.0   63.25
# 9      NaN       1020   6.0      NaN  370.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.loc[df['society'].isnull()]
# Out:
#                   area_type   availability          location       size  \
# 2            Built-up  Area  Ready To Move       Uttarahalli      3 BHK
# 4      Super built-up  Area  Ready To Move          Kothanur      2 BHK
# 8      Super built-up  Area  Ready To Move      Marathahalli      3 BHK
# 9                Plot  Area  Ready To Move      Gandhi Bazar  6 Bedroom
# 10     Super built-up  Area         18-Feb        Whitefield      3 BHK
# ...                     ...            ...               ...        ...
# 13310  Super built-up  Area  Ready To Move      Rachenahalli      2 BHK
# 13311            Plot  Area  Ready To Move  Ramamurthy Nagar  7 Bedroom
# 13312  Super built-up  Area  Ready To Move         Bellandur      2 BHK
# 13316  Super built-up  Area  Ready To Move     Richards Town      4 BHK
# 13319  Super built-up  Area  Ready To Move      Doddathoguru      1 BHK
#
#       society total_sqft  bath  balcony   price
# 2         NaN       1440   2.0      3.0   62.00
# 4         NaN       1200   2.0      1.0   51.00
# 8         NaN       1310   3.0      1.0   63.25
# 9         NaN       1020   6.0      NaN  370.00
# 10        NaN       1800   2.0      2.0   70.00
# ...       ...        ...   ...      ...     ...
# 13310     NaN       1050   2.0      2.0   52.71
# 13311     NaN       1500   9.0      2.0  250.00
# 13312     NaN       1262   2.0      2.0   47.00
# 13316     NaN       3600   5.0      NaN  400.00
# 13319     NaN        550   1.0      1.0   17.00
#
# [5502 rows x 9 columns]

# %%
df['society'].value_counts()
# Out:
# society
# GrrvaGr    80
# PrarePa    76
# Sryalan    59
# Prtates    59
# GMown E    56
#            ..
# SLtalry     1
# Rencyes     1
# DiaveEn     1
# Suiumy      1
# Amionce     1
# Name: count, Length: 2688, dtype: int64

# %%
df.drop(['society'], axis=1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   total_sqft    13320 non-null  object
#  5   bath          13247 non-null  float64
#  6   balcony       12711 non-null  float64
#  7   price         13320 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 832.6+ KB

# %%
df.dropna(inplace=True)

# %%
df['area_type'].value_counts()
# Out:
# area_type
# Super built-up  Area    8481
# Built-up  Area          2310
# Plot  Area              1837
# Carpet  Area              82
# Name: count, dtype: int64

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  12710.000000  12710.000000  12710.000000
# mean       2.617309      1.584343    106.060778
# std        1.226000      0.817287    131.766089
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     49.030000
# 50%        2.000000      2.000000     70.000000
# 75%        3.000000      2.000000    115.000000
# max       40.000000      3.000000   2912.000000

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath  balcony   price
# 0          2 BHK       1056   2.0      1.0   39.07
# 1      4 Bedroom       2600   5.0      3.0  120.00
# 2          3 BHK       1440   2.0      3.0   62.00
# 3          3 BHK       1521   3.0      1.0   95.00
# 4          2 BHK       1200   2.0      1.0   51.00
# ...          ...        ...   ...      ...     ...
# 13314      3 BHK       1715   3.0      3.0  112.00
# 13315  5 Bedroom       3453   4.0      0.0  231.00
# 13317      2 BHK       1141   2.0      1.0   60.00
# 13318      4 BHK       4689   4.0      1.0  488.00
# 13319      1 BHK        550   1.0      1.0   17.00
#
# [12710 rows x 8 columns]

# %%
df['availability'].value_counts()
# Out:
# availability
# Ready To Move    10077
# 18-Dec             291
# 18-May             282
# 18-Apr             261
# 18-Aug             200
#                  ...
# 15-Aug               1
# 16-Nov               1
# 16-Jan               1
# 17-Feb               1
# 14-Jul               1
# Name: count, Length: 78, dtype: int64

# %%
df['availability']= np.where(df['availability']== 'Ready To Move',1,0)

# %%
df['availability'].value_counts()
# Out:
# availability
# 1    10077
# 0     2633
# Name: count, dtype: int64

# %%
df['location'].value_counts()
# Out:
# location
# Whitefield         514
# Sarjapur  Road     372
# Electronic City    300
# Kanakpura Road     261
# Thanisandra        231
#                   ...
# Gulakamale           1
# Duddanahalli         1
# Doddanakunte         1
# Jogupalya            1
# Abshot Layout        1
# Name: count, Length: 1265, dtype: int64

# %%
df.drop(['location'], axis=1, inplace=True)

# %%
plt.figure(figsize= (15,8))
sns.boxplot(x=df['size'], y=df['price'])
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %%
df['size'].value_counts()
# Out:
# size
# 2 BHK         5152
# 3 BHK         4128
# 4 Bedroom      749
# 1 BHK          530
# 3 Bedroom      527
# 4 BHK          489
# 2 Bedroom      328
# 5 Bedroom      263
# 6 Bedroom      169
# 1 Bedroom      105
# 7 Bedroom       69
# 8 Bedroom       65
# 5 BHK           36
# 9 Bedroom       29
# 6 BHK           23
# 7 BHK           16
# 1 RK            13
# 9 BHK            5
# 10 Bedroom       3
# 8 BHK            3
# 11 Bedroom       2
# 11 BHK           1
# 27 BHK           1
# 14 BHK           1
# 43 Bedroom       1
# 12 Bedroom       1
# 13 BHK           1
# Name: count, dtype: int64

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 BHK', '1 RK',
#        '4 BHK', '1 Bedroom', '2 Bedroom', '6 Bedroom', '8 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '11 Bedroom', '43 Bedroom',
#        '14 BHK', '8 BHK', '12 Bedroom', '10 Bedroom', '13 BHK'],
#       dtype=object)

# %%
df['size']= df['size'].str.split(' ').str[0]

# %%
df['size'].value_counts()
# Out:
# size
# 2     5480
# 3     4655
# 4     1238
# 1      648
# 5      299
# 6      192
# 7       85
# 8       68
# 9       34
# 11       3
# 10       3
# 27       1
# 43       1
# 14       1
# 12       1
# 13       1
# Name: count, dtype: int64

# %%
df['size']= df['size'].astype(int)

# %%
df.loc[df['size'] > 10]
# Out:
#                  area_type  availability  size total_sqft  bath  balcony  \
# 459   Super built-up  Area             1    11       5000   9.0      3.0
# 1718  Super built-up  Area             1    27       8000  27.0      0.0
# 1768            Plot  Area             1    11       1200  11.0      0.0
# 3853            Plot  Area             1    11       1200   6.0      3.0
# 4684            Plot  Area             1    43       2400  40.0      0.0
# 4916  Super built-up  Area             1    14       1250  15.0      0.0
# 6533            Plot  Area             1    12       2232   6.0      2.0
# 9935  Super built-up  Area             1    13       5425  13.0      0.0
#
#       price
# 459   360.0
# 1718  230.0
# 1768  170.0
# 3853  150.0
# 4684  660.0
# 4916  125.0
# 6533  300.0
# 9935  275.0

# %%
df.sort_values(by='price', ascending=False)
# Out:
#                   area_type  availability  size    total_sqft  bath  balcony  \
# 11080  Super built-up  Area             0     4          8321   5.0      2.0
# 13200            Plot  Area             1     6          8000   6.0      3.0
# 11763            Plot  Area             1     5          9600   7.0      2.0
# 3180   Super built-up  Area             1     5          8321   5.0      3.0
# 10304            Plot  Area             1     4         10624   4.0      2.0
# ...                     ...           ...   ...           ...   ...      ...
# 11091        Built-up  Area             1     1           410   1.0      1.0
# 4113   Super built-up  Area             0     3  167Sq. Meter   3.0      2.0
# 1471         Built-up  Area             0     1           340   1.0      1.0
# 8594         Built-up  Area             1     1           450   1.0      1.0
# 10526  Super built-up  Area             1     1           284   1.0      1.0
#
#         price
# 11080  2912.0
# 13200  2800.0
# 11763  2736.0
# 3180   2700.0
# 10304  2340.0
# ...       ...
# 11091    10.0
# 4113     10.0
# 1471     10.0
# 8594      9.0
# 10526     8.0
#
# [12710 rows x 7 columns]

# %%
df['total_sqft'].unique()[::]
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def is_float(x):
  try:
    float(x)
  except:
    return False
  return True

# %%
df.loc[~df['total_sqft'].apply(is_float)]
# Out:
#                   area_type  availability  size   total_sqft  bath  balcony  \
# 30     Super built-up  Area             0     4  2100 - 2850   4.0      0.0
# 122    Super built-up  Area             0     4  3067 - 8156   4.0      0.0
# 137    Super built-up  Area             0     2  1042 - 1105   2.0      0.0
# 165    Super built-up  Area             0     2  1145 - 1340   2.0      0.0
# 188    Super built-up  Area             1     2  1015 - 1540   2.0      0.0
# ...                     ...           ...   ...          ...   ...      ...
# 12975  Super built-up  Area             0     2   850 - 1060   2.0      0.0
# 12990  Super built-up  Area             0     3  1804 - 2273   3.0      0.0
# 13059  Super built-up  Area             1     2  1200 - 1470   2.0      0.0
# 13265  Super built-up  Area             0     2  1133 - 1384   2.0      0.0
# 13299  Super built-up  Area             0     4  2830 - 2882   5.0      0.0
#
#          price
# 30     186.000
# 122    477.000
# 137     54.005
# 165     43.490
# 188     56.800
# ...        ...
# 12975   38.190
# 12990  122.000
# 13059   72.760
# 13265   59.135
# 13299  154.500
#
# [186 rows x 7 columns]

# %%
def convert_to_sqft(x):
  tokens= str(x).split('-')
  if len(tokens) == 2:
    return (float(tokens[0]) + float(tokens[1]))/2
  try:
    return float(x)
  except:
    return None

# %%
df['total_sqft']= df['total_sqft'].apply(convert_to_sqft)

# %%
df.loc[~df['total_sqft'].apply(is_float)]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, size, total_sqft, bath, balcony, price]
# Index: []

# %%
df.loc[30]
# Out:
# area_type       Super built-up  Area
# availability                       0
# size                               4
# total_sqft                    2475.0
# bath                             4.0
# balcony                          0.0
# price                          186.0
# Name: 30, dtype: object

# %%
df['total_sqft'].unique()
# Out:
# array([1056. , 2600. , 1440. , ..., 1258.5,  774. , 4689. ])

# %%
# def convert_to_sqft(values):
#     result = []

#     for v in values:
#         s = str(v).lower().strip()

#         if 'sq' in s:
#           val= float(''.join(filter(str.isdigit, str(s))))
#           result.append(val * 10.764)
#         elif 'acre' in s:
#           val= float(''.join(filter(str.isdigit, str(s))))
#           result.append(val * 43560)
#         elif 'cent' in s:
#           val= float(''.join(filter(str.isdigit, str(s))))
#           result.append(val * 435.6)
#         elif 'ground' in s:
#           val= float(''.join(filter(str.isdigit, str(s))))
#           result.append(val * 2400)
#         else:
#           result.append(v)

#     return result

# %%
# x= list(df['total_sqft'])
# # df['total_sqft']= convert_to_sqft(x)
# # print(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12710 entries, 0 to 13319
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12710 non-null  object
#  1   availability  12710 non-null  int64
#  2   size          12710 non-null  int64
#  3   total_sqft    12668 non-null  float64
#  4   bath          12710 non-null  float64
#  5   balcony       12710 non-null  float64
#  6   price         12710 non-null  float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.3+ MB

# %%
df.dropna(axis=0, inplace=True)

# %%
df.describe()
# Out:
#        availability          size    total_sqft          bath       balcony  \
# count  12668.000000  12668.000000  12668.000000  12668.000000  12668.000000
# mean       0.792706      2.736422   1511.835167      2.616277      1.585649
# std        0.405384      1.202643   1162.097276      1.223882      0.816758
# min        0.000000      1.000000      5.000000      1.000000      0.000000
# 25%        1.000000      2.000000   1100.000000      2.000000      1.000000
# 50%        1.000000      3.000000   1260.000000      2.000000      2.000000
# 75%        1.000000      3.000000   1640.000000      3.000000      2.000000
# max        1.000000     43.000000  52272.000000     40.000000      3.000000
#
#               price
# count  12668.000000
# mean     105.952648
# std      131.813137
# min        8.000000
# 25%       49.015000
# 50%       70.000000
# 75%      115.000000
# max     2912.000000

# %%
df['bath'].unique()
# Out:
# array([ 2.,  5.,  3.,  4.,  1.,  8.,  7.,  6.,  9., 27., 11., 12., 10.,
#        40., 15., 13.])

# %%
df['bath'].value_counts()
# Out:
# bath
# 2.0     6820
# 3.0     3134
# 4.0     1105
# 1.0      779
# 5.0      428
# 6.0      240
# 7.0       82
# 8.0       42
# 9.0       26
# 10.0       6
# 11.0       1
# 27.0       1
# 12.0       1
# 40.0       1
# 15.0       1
# 13.0       1
# Name: count, dtype: int64

# %%
df['bath']= df["bath"].astype(int)

# %%
df.loc[df['bath'] > 5].sort_values(by='price', ascending=False)
# Out:
#                   area_type  availability  size  total_sqft  bath  balcony  \
# 13200            Plot  Area             1     6      8000.0     6      3.0
# 11763            Plot  Area             1     5      9600.0     7      2.0
# 605    Super built-up  Area             0     7     12000.0     7      3.0
# 408    Super built-up  Area             0     7     12000.0     6      3.0
# 10429            Plot  Area             1     4      7500.0     6      2.0
# ...                     ...           ...   ...         ...   ...      ...
# 3437             Plot  Area             1     6       600.0     7      2.0
# 6068             Plot  Area             1     8       600.0     6      2.0
# 11002            Plot  Area             1     4      1200.0     6      3.0
# 8352         Built-up  Area             1     6      2500.0     6      3.0
# 1671         Built-up  Area             1     5      1800.0     6      0.0
#
#         price
# 13200  2800.0
# 11763  2736.0
# 605    2200.0
# 408    2200.0
# 10429  1800.0
# ...       ...
# 3437     63.0
# 6068     60.0
# 11002    60.0
# 8352     58.0
# 1671     44.5
#
# [402 rows x 7 columns]

# %%
df['balcony'].unique()
# Out:
# array([1., 3., 2., 0.])

# %%
df['balcony']= df['balcony'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12668 entries, 0 to 13319
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12668 non-null  object
#  1   availability  12668 non-null  int64
#  2   size          12668 non-null  int64
#  3   total_sqft    12668 non-null  float64
#  4   bath          12668 non-null  int64
#  5   balcony       12668 non-null  int64
#  6   price         12668 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 791.8+ KB

# %%
df
# Out:
#                   area_type  availability  size  total_sqft  bath  balcony  \
# 0      Super built-up  Area             0     2      1056.0     2        1
# 1                Plot  Area             1     4      2600.0     5        3
# 2            Built-up  Area             1     3      1440.0     2        3
# 3      Super built-up  Area             1     3      1521.0     3        1
# 4      Super built-up  Area             1     2      1200.0     2        1
# ...                     ...           ...   ...         ...   ...      ...
# 13314  Super built-up  Area             1     3      1715.0     3        3
# 13315        Built-up  Area             1     5      3453.0     4        0
# 13317        Built-up  Area             1     2      1141.0     2        1
# 13318  Super built-up  Area             0     4      4689.0     4        1
# 13319  Super built-up  Area             1     1       550.0     1        1
#
#         price
# 0       39.07
# 1      120.00
# 2       62.00
# 3       95.00
# 4       51.00
# ...       ...
# 13314  112.00
# 13315  231.00
# 13317   60.00
# 13318  488.00
# 13319   17.00
#
# [12668 rows x 7 columns]

# %%
df.describe()
# Out:
#        availability          size    total_sqft          bath       balcony  \
# count  12668.000000  12668.000000  12668.000000  12668.000000  12668.000000
# mean       0.792706      2.736422   1511.835167      2.616277      1.585649
# std        0.405384      1.202643   1162.097276      1.223882      0.816758
# min        0.000000      1.000000      5.000000      1.000000      0.000000
# 25%        1.000000      2.000000   1100.000000      2.000000      1.000000
# 50%        1.000000      3.000000   1260.000000      2.000000      2.000000
# 75%        1.000000      3.000000   1640.000000      3.000000      2.000000
# max        1.000000     43.000000  52272.000000     40.000000      3.000000
#
#               price
# count  12668.000000
# mean     105.952648
# std      131.813137
# min        8.000000
# 25%       49.015000
# 50%       70.000000
# 75%      115.000000
# max     2912.000000

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
# sns.displot(df['total_sqft'])

# %%
# sns.boxplot(x= df['area_type'], y= df['price'])

# %%
df['availability'].value_counts()
# Out:
# availability
# 1    10042
# 0     2626
# Name: count, dtype: int64

# %%
sns.boxplot(x= df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
idx= df['price'].loc[df['price'] > 115 ].index
df.drop(idx, inplace=True)

# %%
sns.boxplot(x= df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
df.describe()
# Out:
#        availability         size    total_sqft         bath      balcony  \
# count   9591.000000  9591.000000   9591.000000  9591.000000  9591.000000
# mean       0.778751     2.406006   1224.313012     2.239183     1.525388
# std        0.415109     0.816604    371.264861     0.755882     0.779399
# min        0.000000     1.000000      5.000000     1.000000     0.000000
# 25%        1.000000     2.000000   1050.000000     2.000000     1.000000
# 50%        1.000000     2.000000   1200.000000     2.000000     1.000000
# 75%        1.000000     3.000000   1400.000000     2.000000     2.000000
# max        1.000000     9.000000  10961.000000     9.000000     3.000000
#
#              price
# count  9591.000000
# mean     61.876421
# std      22.832200
# min       8.000000
# 25%      45.000000
# 50%      59.000000
# 75%      77.260000
# max     115.000000

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df[(df.total_sqft / df.size) < 300]
# Out:
#                   area_type  availability  size  total_sqft  bath  balcony  \
# 0      Super built-up  Area             0     2      1056.0     2        1
# 2            Built-up  Area             1     3      1440.0     2        3
# 3      Super built-up  Area             1     3      1521.0     3        1
# 4      Super built-up  Area             1     2      1200.0     2        1
# 5      Super built-up  Area             1     2      1170.0     2        1
# ...                     ...           ...   ...         ...   ...      ...
# 13312  Super built-up  Area             1     2      1262.0     2        2
# 13313  Super built-up  Area             1     3      1345.0     2        1
# 13314  Super built-up  Area             1     3      1715.0     3        3
# 13317        Built-up  Area             1     2      1141.0     2        1
# 13319  Super built-up  Area             1     1       550.0     1        1
#
#         price
# 0       39.07
# 2       62.00
# 3       95.00
# 4       51.00
# 5       38.00
# ...       ...
# 13312   47.00
# 13313   57.00
# 13314  112.00
# 13317   60.00
# 13319   17.00
#
# [9591 rows x 7 columns]

# %%
df.sort_values(by='total_sqft', ascending=True).head(10)
# Out:
#                   area_type  availability  size  total_sqft  bath  balcony  \
# 4972         Built-up  Area             1     7         5.0     7        3
# 349              Plot  Area             0     3        11.0     3        2
# 1020           Carpet  Area             1     1        15.0     1        0
# 5970             Plot  Area             1     1        45.0     1        0
# 13216  Super built-up  Area             1     1       250.0     2        2
# 119              Plot  Area             1     2       276.0     3        3
# 10526  Super built-up  Area             1     1       284.0     1        1
# 2486   Super built-up  Area             0     1       296.0     1        0
# 4853           Carpet  Area             1     1       300.0     1        1
# 11495  Super built-up  Area             1     2       302.0     2        1
#
#         price
# 4972   115.00
# 349     74.00
# 1020    30.00
# 5970    23.00
# 13216   40.00
# 119     23.00
# 10526    8.00
# 2486    22.89
# 4853    20.00
# 11495   25.00

# %%
idx= df.loc[df['total_sqft'] < 300].index
df.drop(idx, inplace=True)
idx= df.loc[df['total_sqft'] > 3000].index
df.drop(idx, inplace=True)

# %%
df.sort_values(by='total_sqft', ascending=False).head(10)
# Out:
#                   area_type  availability  size  total_sqft  bath  balcony  \
# 4108   Super built-up  Area             1     4     3000.00     5        2
# 6198         Built-up  Area             1     4     3000.00     4        0
# 6794         Built-up  Area             1     3     3000.00     3        2
# 12068        Built-up  Area             1     6     2999.97     6        0
# 1212             Plot  Area             1     5     2900.00     5        2
# 12977        Built-up  Area             1     7     2800.00     6        1
# 2237             Plot  Area             1     4     2800.00     4        2
# 11901        Built-up  Area             1     7     2800.00     5        3
# 5912             Plot  Area             1     6     2800.00     4        3
# 3205   Super built-up  Area             1     3     2721.00     3        2
#
#        price
# 4108   100.0
# 6198   100.0
# 6794    60.0
# 12068  110.0
# 1212    90.0
# 12977  110.0
# 2237    89.0
# 11901   95.0
# 5912   100.0
# 3205   113.0

# %%
df['total_sqft'].describe()
# Out:
# count    9574.000000
# mean     1221.083778
# std       332.352296
# min       300.000000
# 25%      1050.000000
# 50%      1200.000000
# 75%      1400.000000
# max      3000.000000
# Name: total_sqft, dtype: float64

# %%
sns.boxplot(x= 'area_type', y= 'price', data= df)
# Out:
# <Axes: xlabel='area_type', ylabel='price'>

# %%
sns.boxplot(x= 'availability', y= 'price', data= df)
# Out:
# <Axes: xlabel='availability', ylabel='price'>

# %%
sns.boxplot(x= 'size', y= 'price', data= df)
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %%
plt.scatter(data=df, x="price", y= 'total_sqft')
# Heteroscedasticity detected, linear model fails, but knn will deal with it nicely

# %%
sns.boxplot(x= 'bath', y= 'price', data= df)
# Out:
# <Axes: xlabel='bath', ylabel='price'>

# %%
sns.boxplot(x= 'balcony', y= 'price', data= df)
# Out:
# <Axes: xlabel='balcony', ylabel='price'>

# %%
df= pd.get_dummies(df, columns=['area_type'], drop_first=True)

# %%
df
# Out:
#        availability  size  total_sqft  bath  balcony   price  \
# 0                 0     2      1056.0     2        1   39.07
# 2                 1     3      1440.0     2        3   62.00
# 3                 1     3      1521.0     3        1   95.00
# 4                 1     2      1200.0     2        1   51.00
# 5                 1     2      1170.0     2        1   38.00
# ...             ...   ...         ...   ...      ...     ...
# 13312             1     2      1262.0     2        2   47.00
# 13313             1     3      1345.0     2        1   57.00
# 13314             1     3      1715.0     3        3  112.00
# 13317             1     2      1141.0     2        1   60.00
# 13319             1     1       550.0     1        1   17.00
#
#        area_type_Carpet  Area  area_type_Plot  Area  \
# 0                       False                 False
# 2                       False                 False
# 3                       False                 False
# 4                       False                 False
# 5                       False                 False
# ...                       ...                   ...
# 13312                   False                 False
# 13313                   False                 False
# 13314                   False                 False
# 13317                   False                 False
# 13319                   False                 False
#
#        area_type_Super built-up  Area
# 0                                True
# 2                               False
# 3                                True
# 4                                True
# 5                                True
# ...                               ...
# 13312                            True
# 13313                            True
# 13314                            True
# 13317                           False
# 13319                            True
#
# [9574 rows x 9 columns]

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Splitting data into Train and Testing data

# %%
X= df.drop(['price'], axis=1)
Y= df['price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size=0.25, random_state=99)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((7180, 8), (2394, 8), (7180,), (2394,))

# %% [markdown]
# Standard Scaling (Normalization)

# %%
plt.figure(figsize= (16,6))
plt.subplot(1,2,1)
sns.boxplot(x_train)
plt.subplot(1,2,2)
sns.boxplot(x_test)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()
x_train= scale.fit_transform(x_train)
x_test= scale.transform(x_test)

# %%
plt.figure(figsize= (16,6))
plt.subplot(1,2,1)
sns.boxplot(x_train)
plt.subplot(1,2,2)
sns.boxplot(x_test)
# Out:
# <Axes: >

# %% [markdown]
# Model Training

# %%
from sklearn.neighbors import KNeighborsRegressor
model= KNeighborsRegressor(n_neighbors=5)
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
model.score(x_train, y_train), model.score(x_test, y_test)
# Out:
# (0.6691781846671225, 0.5207381876753022)

# %% [markdown]
# model score with Standard Scaling
# (0.6684193706378907, 0.5311039327807539)
#
# model score without Standard Scaling
# (0.6684193706378907, 0.5111039327807539)
#
# model score with n_neighbors=7
# (0.6509993482016965, 0.5447014561629178)
#
# model score with n_neighbors=9
# (0.6371863624529819, 0.5483369938984607)
#
# model score with n_neighbors=11
# (0.6204373235906126, 0.5486789005861188)
#
# model score with n_neighbors=17
# (0.6004373235906126, 0.5486789005861188)

# %%
y_pred= model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse= mean_squared_error(y_test, y_pred)
mae= mean_absolute_error(y_test, y_pred)
r2= r2_score(y_test, y_pred)

print(mse, mae, r2)
# Out:
# 243.3741216177945 11.708951963241438 0.5207381876753022

# %%
from sklearn.svm import SVR
model= SVR(kernel= 'rbf',
           epsilon= 0.3)
model.fit(x_train, y_train)
# Out:
# SVR(epsilon=0.3)

# %%
y_pred= model.predict(x_test)
print(model.score(x_train, y_train), model.score(x_test, y_test))
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse= mean_squared_error(y_test, y_pred)
mae= mean_absolute_error(y_test, y_pred)
r2= r2_score(y_test, y_pred)

print(mse, mae, r2)
# Out:
# 0.5408414648918487 0.508566112918793
# 249.55522748926455 12.068474034561516 0.508566112918793
