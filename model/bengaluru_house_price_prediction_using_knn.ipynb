# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Bengaluru_House_Data.csv')
df.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.loc[df['society'].isnull()]
# Out:
#                   area_type   availability          location       size  \
# 2            Built-up  Area  Ready To Move       Uttarahalli      3 BHK
# 4      Super built-up  Area  Ready To Move          Kothanur      2 BHK
# 8      Super built-up  Area  Ready To Move      Marathahalli      3 BHK
# 9                Plot  Area  Ready To Move      Gandhi Bazar  6 Bedroom
# 10     Super built-up  Area         18-Feb        Whitefield      3 BHK
# ...                     ...            ...               ...        ...
# 13310  Super built-up  Area  Ready To Move      Rachenahalli      2 BHK
# 13311            Plot  Area  Ready To Move  Ramamurthy Nagar  7 Bedroom
# 13312  Super built-up  Area  Ready To Move         Bellandur      2 BHK
# 13316  Super built-up  Area  Ready To Move     Richards Town      4 BHK
# 13319  Super built-up  Area  Ready To Move      Doddathoguru      1 BHK
#
#       society total_sqft  bath  balcony   price
# 2         NaN       1440   2.0      3.0   62.00
# ...

# %%
df['society'].value_counts()
# Out:
# society
# GrrvaGr    80
# PrarePa    76
# Sryalan    59
# Prtates    59
# GMown E    56
#            ..
# SLtalry     1
# Rencyes     1
# DiaveEn     1
# Suiumy      1
# Amionce     1
# Name: count, Length: 2688, dtype: int64

# %%
# df.drop(['society'], axis=1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
# df.dropna(inplace=True)

# %%
df['area_type'].value_counts()
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['availability'].value_counts()
# Out:
# availability
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 16-Oct               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: count, Length: 81, dtype: int64

# %%
df['availability']= np.where(df['availability']== 'Ready To Move',1,0)

# %%
df['availability'].value_counts()
# Out:
# availability
# 1    10581
# 0     2739
# Name: count, dtype: int64

# %%
df['location'].value_counts()
# Out:
# location
# Whitefield                         540
# Sarjapur  Road                     399
# Electronic City                    302
# Kanakpura Road                     273
# Thanisandra                        234
#                                   ...
# 3rd Stage Raja Rajeshwari Nagar      1
# Chuchangatta Colony                  1
# Electronic City Phase 1,             1
# Chikbasavanapura                     1
# Abshot Layout                        1
# Name: count, Length: 1305, dtype: int64

# %%
# df.drop(['location'], axis=1, inplace=True)

# %%
plt.figure(figsize= (15,8))
sns.boxplot(x=df['size'], y=df['price'])
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %%
df['size'].value_counts()
# Out:
# size
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 10 BHK           2
# 11 Bedroom       2
# 27 BHK           1
# 19 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 14 BHK           1
# 12 Bedroom       1
# 13 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df['size']= df['size'].str.split(' ').str[0]

# %%
df['size'].value_counts()
# Out:
# size
# 2     5528
# 3     4857
# 4     1417
# 1      656
# 5      356
# 6      221
# 7      100
# 8       89
# 9       54
# 10      14
# 11       4
# 27       1
# 19       1
# 16       1
# 43       1
# 14       1
# 12       1
# 13       1
# 18       1
# Name: count, dtype: int64

# %%
idx= df.loc[df['size'].isnull() == True].index
df.drop(idx,axis=0,inplace=True)
idx
# Out:
# Index([  579,  1775,  2264,  2809,  2862,  5333,  6423,  6636,  6719,  7680,
#         8306,  8565,  8703, 10634, 11019, 11569],
#       dtype='int64')

# %%
df.shape
# Out:
# (13304, 9)

# %%
df['size']= df['size'].astype(int)

# %%
df.loc[df['size'] > 10]
# Out:
#                   area_type  availability                       location  \
# 459    Super built-up  Area             1                   1 Giri Nagar
# 1718   Super built-up  Area             1      2Electronic City Phase II
# 1768             Plot  Area             1             1 Ramamurthy Nagar
# 3379   Super built-up  Area             1                 1Hanuman Nagar
# 3609   Super built-up  Area             1  Koramangala Industrial Layout
# 3853             Plot  Area             1              1 Annasandrapalya
# 4684             Plot  Area             1                    Munnekollal
# 4916   Super built-up  Area             1                  1Channasandra
# 6533             Plot  Area             1                    Mysore Road
# 7979   Super built-up  Area             1                  1 Immadihalli
# 9935   Super built-up  Area             1                  1Hoysalanagar
# 11559            Plot  Area             0                  1Kasavanhalli
#
# ...

# %%
df.sort_values(by='price', ascending=False)
# Out:
#                   area_type  availability            location  size  society  \
# 13067            Plot  Area             1      Defence Colony    10      NaN
# 11080  Super built-up  Area             0         Ashok Nagar     4      NaN
# 13200            Plot  Area             1      Defence Colony     6      NaN
# 11763            Plot  Area             1     Sadashiva Nagar     5      NaN
# 3180   Super built-up  Area             1     Shanthala Nagar     5  Kierser
# ...                     ...           ...                 ...   ...      ...
# 5410   Super built-up  Area             1            Attibele     1  Jae 1hu
# 11091        Built-up  Area             1            Attibele     1      NaN
# 1471         Built-up  Area             0             Kengeri     1      NaN
# 8594         Built-up  Area             1          Chandapura     1      NaN
# 10526  Super built-up  Area             1  Yelahanka New Town     1  KHatsFl
#
#       total_sqft  bath  balcony   price
# ...

# %%
df['total_sqft'].unique()[::]
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def is_float(x):
  try:
    float(x)
  except:
    return False
  return True

# %%
df.loc[~df['total_sqft'].apply(is_float)]
# Out:
#                   area_type  availability            location  size  society  \
# 30     Super built-up  Area             0           Yelahanka     4  LedorSa
# 56           Built-up  Area             0         Devanahalli     4  BrereAt
# 81           Built-up  Area             0         Hennur Road     4  Gollela
# 122    Super built-up  Area             0              Hebbal     4  SNontle
# 137    Super built-up  Area             0  8th Phase JP Nagar     2  Vaarech
# ...                     ...           ...                 ...   ...      ...
# 12990  Super built-up  Area             0      Talaghattapura     3  Sodgere
# 13059  Super built-up  Area             1              Harlur     2  Shodsir
# 13240  Super built-up  Area             1         Devanahalli     1  Pardsri
# 13265  Super built-up  Area             0               Hoodi     2  Ranuetz
# 13299  Super built-up  Area             0          Whitefield     4  Prtates
#
#         total_sqft  bath  balcony    price
# ...

# %%
def convert_to_sqft(x):
  tokens= str(x).split('-')
  if len(tokens) == 2:
    return (float(tokens[0]) + float(tokens[1]))/2
  try:
    return float(x)
  except:
    return None

# %%
df['total_sqft']= df['total_sqft'].apply(convert_to_sqft)

# %%
df.loc[~df['total_sqft'].apply(is_float)]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price]
# Index: []

# %%
df.loc[30]
# Out:
# area_type       Super built-up  Area
# availability                       0
# location                   Yelahanka
# size                               4
# society                      LedorSa
# total_sqft                    2475.0
# bath                             4.0
# balcony                          0.0
# price                          186.0
# Name: 30, dtype: object

# %%
df['total_sqft'].unique()
# Out:
# array([1056. , 2600. , 1440. , ..., 1258.5,  774. , 4689. ])

# %%
# def convert_to_sqft(values):
#     result = []

#     for v in values:
#         s = str(v).lower().strip()

#         if 'sq' in s:
#           val= float(''.join(filter(str.isdigit, str(s))))
#           result.append(val * 10.764)
#         elif 'acre' in s:
#           val= float(''.join(filter(str.isdigit, str(s))))
#           result.append(val * 43560)
#         elif 'cent' in s:
#           val= float(''.join(filter(str.isdigit, str(s))))
#           result.append(val * 435.6)
#         elif 'ground' in s:
#           val= float(''.join(filter(str.isdigit, str(s))))
#           result.append(val * 2400)
#         else:
#           result.append(v)

#     return result

# %%
# x= list(df['total_sqft'])
# # df['total_sqft']= convert_to_sqft(x)
# # print(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13304 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13304 non-null  object
#  1   availability  13304 non-null  int64
#  2   location      13303 non-null  object
#  3   size          13304 non-null  int64
#  4   society       7805 non-null   object
#  5   total_sqft    13258 non-null  float64
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13304 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df['price_per_sqft']= df['price']*100000/df['total_sqft']

# %%
df.head()
# Out:
#               area_type  availability                  location  size  \
# 0  Super built-up  Area             0  Electronic City Phase II     2
# 1            Plot  Area             1          Chikka Tirupathi     4
# 2        Built-up  Area             1               Uttarahalli     3
# 3  Super built-up  Area             1        Lingadheeranahalli     3
# 4  Super built-up  Area             1                  Kothanur     2
#
#    society  total_sqft  bath  balcony   price  price_per_sqft
# 0  Coomee       1056.0   2.0      1.0   39.07     3699.810606
# 1  Theanmp      2600.0   5.0      3.0  120.00     4615.384615
# 2      NaN      1440.0   2.0      3.0   62.00     4305.555556
# 3  Soiewre      1521.0   3.0      1.0   95.00     6245.890861
# 4      NaN      1200.0   2.0      1.0   51.00     4250.000000

# %%
df['location'].unique().size
# Out:
# 1305

# %%
df['location'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 13304 entries, 0 to 13319
# Series name: location
# Non-Null Count  Dtype
# --------------  -----
# 13303 non-null  object
# dtypes: object(1)
# memory usage: 723.9+ KB

# %%
idx= df.loc[df['location'].isnull()].index
df.drop(idx, axis=0, inplace=True)

# %%
df['location']= df['location'].apply(lambda x: x.strip())

# %%
location_counts= df['location'].value_counts(ascending=False)

# %%
location_counts
# Out:
# location
# Whitefield                              540
# Sarjapur  Road                          397
# Electronic City                         304
# Kanakpura Road                          273
# Thanisandra                             237
#                                        ...
# Duddanahalli                              1
# Doddanakunte                              1
# Jogupalya                                 1
# Subhash Nagar                             1
# Kengeri Satellite Town KHB Apartment      1
# Name: count, Length: 1293, dtype: int64

# %%
location_counts[location_counts<=10].size
# Out:
# 1052

# %%
df['location']= df['location'].apply(lambda x: 'other' if x in location_counts[location_counts<=10] else x)

# %%
df['location'].unique().size
# Out:
# 242

# %%
df.describe()
# Out:
#        availability          size    total_sqft          bath       balcony  \
# count  13303.000000  13303.000000  13257.000000  13246.000000  12710.000000
# mean       0.795309      2.803728   1558.809175      2.692586      1.584343
# std        0.403491      1.295022   1238.478935      1.341506      0.817287
# min        0.000000      1.000000      1.000000      1.000000      0.000000
# 25%        1.000000      2.000000   1100.000000      2.000000      1.000000
# 50%        1.000000      3.000000   1275.000000      2.000000      2.000000
# 75%        1.000000      3.000000   1680.000000      3.000000      2.000000
# max        1.000000     43.000000  52272.000000     40.000000      3.000000
#
#               price  price_per_sqft
# count  13303.000000    1.325700e+04
# mean     112.584033    7.912825e+03
# std      148.993820    1.064976e+05
# min        8.000000    2.678298e+02
# 25%       50.000000    4.271186e+03
# 50%       72.000000    5.438596e+03
# ...

# %%
df['bath'].unique()
# Out:
# array([ 2.,  5.,  3.,  4.,  6.,  1.,  9., nan,  8.,  7., 11., 10., 14.,
#        27., 12., 16., 40., 15., 13., 18.])

# %%
df['bath'].value_counts()
# Out:
# bath
# 2.0     6908
# 3.0     3285
# 4.0     1226
# 1.0      788
# 5.0      524
# 6.0      273
# 7.0      102
# 8.0       64
# 9.0       43
# 10.0      13
# 12.0       7
# 11.0       3
# 13.0       3
# 16.0       2
# 27.0       1
# 14.0       1
# 40.0       1
# 15.0       1
# 18.0       1
# Name: count, dtype: int64

# %%
plt.hist(df.bath,rwidth=0.8)
plt.xlabel("Number of bathrooms")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df= df.loc[(df['bath']< df['size']+2)]

# %%
df.shape
# Out:
# (10141, 10)

# %%
df['bath']= df["bath"].astype(int)
# Out:
# /tmp/ipython-input-3267139018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bath']= df["bath"].astype(int)

# %%
df['balcony'].unique()
# Out:
# array([ 1.,  2.,  3.,  0., nan])

# %%
# idx= df.loc[df['balcony'].isnull()].index
# df.drop(idx, axis=0, inplace= True)
# idx

# %%
# df['balcony']= df['balcony'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10141 entries, 0 to 10285
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   area_type       10141 non-null  object
#  1   availability    10141 non-null  int64
#  2   location        10141 non-null  object
#  3   size            10141 non-null  int64
#  4   society         6438 non-null   object
#  5   total_sqft      10141 non-null  float64
#  6   bath            10141 non-null  int64
#  7   balcony         9841 non-null   float64
#  8   price           10141 non-null  float64
#  9   price_per_sqft  10141 non-null  float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 871.5+ KB

# %%
df['availability'].value_counts()
# Out:
# availability
# 1    8012
# 0    2129
# Name: count, dtype: int64

# %%
# sns.boxplot(x= df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# idx= df['price'].loc[df['price'] > 115 ].index
# df.drop(idx, inplace=True)

# %%
# sns.boxplot(x= df['price'])

# %%
df.shape
# Out:
# (10141, 10)

# %%
df['total_sqft'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10141 entries, 0 to 10285
# Series name: total_sqft
# Non-Null Count  Dtype
# --------------  -----
# 10141 non-null  float64
# dtypes: float64(1)
# memory usage: 158.5 KB

# %%
idx= df.loc[df['total_sqft'].isnull()].index
df.drop(idx, inplace=True)
idx
# Out:
# /tmp/ipython-input-1636802915.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(idx, inplace=True)
# Index([], dtype='int64')

# %%
df['total_sqft'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10141 entries, 0 to 10285
# Series name: total_sqft
# Non-Null Count  Dtype
# --------------  -----
# 10141 non-null  float64
# dtypes: float64(1)
# memory usage: 158.5 KB

# %%
df.loc[(df['total_sqft']/df['size'] < 300)].sort_values(by='total_sqft', ascending=True)
# Out:
#                  area_type  availability              location  size  society  \
# 4086            Plot  Area             1        Sarjapur  Road     4      NaN
# 4972        Built-up  Area             1                 other     7      NaN
# 349             Plot  Area             0                 other     3  PrhyaK
# 1020          Carpet  Area             1                 other     1      NaN
# 1122        Built-up  Area             1                 other     5      NaN
# ...                    ...           ...                   ...   ...      ...
# 6505            Plot  Area             1          Yeshwanthpur     9      NaN
# 4691            Plot  Area             1                 other    10      NaN
# 1593            Plot  Area             1              JP Nagar     9      NaN
# 6937            Plot  Area             1  5th Block Hbr Layout     9      NaN
# 1718  Super built-up  Area             1                 other    27      NaN
#
# ...

# %%
df= df.loc[~(df['total_sqft']/ df['size'] < 300)]

# %%
df.shape
# Out:
# (12513, 10)

# %%
df['price_per_sqft'].describe()
# Out:
# count     12513.000000
# mean       6307.441644
# std        4160.931610
# min         267.829813
# 25%        4210.526316
# 50%        5295.007564
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
df.groupby('location')['price_per_sqft'].mean().sort_values(ascending= False)
# Out:
# location
# Cunningham Road                20632.478844
# HAL 2nd Stage                  19134.461565
# Bommenahalli                   15361.577714
# Giri Nagar                     14587.820513
# 2nd Stage Nagarbhavi           14381.275720
#                                    ...
# Kammasandra                     3489.050503
# Ananth Nagar                    3320.335293
# Kereguddadahalli                3259.150303
# Bommasandra Industrial Area     3117.507926
# Chandapura                      3041.504808
# Name: price_per_sqft, Length: 242, dtype: float64

# %%
def remove_outliers(df):
  df_out= pd.DataFrame()
  for key, subdf in df.groupby('location'):
    m= np.mean(subdf.price_per_sqft)
    st= np.std(subdf.price_per_sqft)
    reduced_df= subdf[(subdf.price_per_sqft >m-st) & (subdf.price_per_sqft <m+st)]
    df_out= pd.concat([df_out, reduced_df], ignore_index=True)
  return df_out

# %%
df= remove_outliers(df)

# %%
df.shape
# Out:
# (10286, 10)

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('size'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('size'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')

# %%
df= remove_bhk_outliers(df)

# %%
plt.figure(figsize= (10,4))
plt.hist(data= df, x= 'price_per_sqft', rwidth=0.8)
plt.xlabel('price_per_sqft')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
# df.sort_values(by='total_sqft', ascending=True).head(10)

# %%
# idx= df.loc[df['total_sqft'] < 300].index
# df.drop(idx, inplace=True)
# idx= df.loc[df['total_sqft'] > 3000].index
# df.drop(idx, inplace=True)

# %%
# df.sort_values(by='total_sqft', ascending=False).head(10)

# %%
sns.boxplot(x= 'area_type', y= 'price', data= df)
# Out:
# <Axes: xlabel='area_type', ylabel='price'>

# %%
sns.boxplot(x= 'availability', y= 'price', data= df)
# Out:
# <Axes: xlabel='availability', ylabel='price'>

# %%
sns.boxplot(x= 'size', y= 'price', data= df)
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %%
plt.scatter(data=df, x="price", y= 'total_sqft')
# Heteroscedasticity detected, linear model fails, but knn will deal with it nicely

# %%
sns.boxplot(x= 'bath', y= 'price', data= df)
# Out:
# <Axes: xlabel='bath', ylabel='price'>

# %%
sns.boxplot(x= 'balcony', y= 'price', data= df)
# Out:
# <Axes: xlabel='balcony', ylabel='price'>

# %%
# df= pd.get_dummies(df, columns=['area_type'], drop_first=True)

# %%
df
# Out:
#                   area_type  availability             location  size  society  \
# 0      Super built-up  Area             0  1st Block Jayanagar     4      NaN
# 1      Super built-up  Area             0  1st Block Jayanagar     3      NaN
# 2      Super built-up  Area             1  1st Block Jayanagar     3      NaN
# 3            Built-up  Area             0  1st Block Jayanagar     3  Bhsic C
# 4      Super built-up  Area             0  1st Block Jayanagar     2      NaN
# ...                     ...           ...                  ...   ...      ...
# 10277          Carpet  Area             0                other     2      NaN
# 10278  Super built-up  Area             1                other     1      NaN
# 10281  Super built-up  Area             1                other     2  OlarkLa
# 10282            Plot  Area             0                other     1      NaN
# 10285  Super built-up  Area             1                other     4      NaN
#
# ...

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price', 'price_per_sqft'],
#       dtype='object')

# %%
df_final= df.drop(columns=['area_type', 'availability','society', 'balcony', 'price_per_sqft'], axis=1)

# %%
dummies= pd.get_dummies(df['location'], drop_first=True)
df_final= pd.concat([df_final, dummies], axis=1)

# %%
# from sklearn.preprocessing import LabelEncoder
# le= LabelEncoder()
# df_final['location']= le.fit_transform(df_final['location'])

# %%
df_final.drop(columns=['location'], axis=1, inplace=True)

# %%
df_final
# Out:
#        size  total_sqft  bath  price  1st Phase JP Nagar  \
# 0         4      2850.0     4  428.0               False
# 1         3      1630.0     3  194.0               False
# 2         3      1875.0     2  235.0               False
# 3         3      1200.0     2  130.0               False
# 4         2      1235.0     2  148.0               False
# ...     ...         ...   ...    ...                 ...
# 10277     2      1200.0     2   70.0               False
# 10278     1      1800.0     1  200.0               False
# 10281     2      1353.0     2  110.0               False
# 10282     1       812.0     1   26.0               False
# 10285     4      3600.0     5  400.0               False
#
#        2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                          False                 False                 False
# 1                          False                 False                 False
# ...

# %%
# sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# Splitting data into Train and Testing data

# %%
X= df_final.drop(['price'], axis=1)
Y= df_final['price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size=0.2, random_state=10)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((5799, 244), (1450, 244), (5799,), (1450,))

# %% [markdown]
# Standard Scaling (Normalization)

# %%
# from sklearn.preprocessing import StandardScaler
# scale= StandardScaler()
# x_train= scale.fit_transform(x_train)
# x_test= scale.transform(x_test)

# %% [markdown]
# Model Training

# %%
from sklearn.neighbors import KNeighborsRegressor
model= KNeighborsRegressor(n_neighbors=3)
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
model.score(x_train, y_train), model.score(x_test, y_test)
# Out:
# (0.8501624991394547, 0.7061426079498037)

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)

cross_val_score(KNeighborsRegressor(), X, Y, cv=cv)
# Out:
# array([0.70738029, 0.67660945, 0.70833089, 0.64528788, 0.62695957,
#        0.68415102, 0.69014199, 0.63775599, 0.69073685, 0.74667801])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {

            }
        },
        'Knn': {
            'model': KNeighborsRegressor(),
            'params':{
                'n_neighbors': [3,5,7,9,11]
            }

        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,Y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,Y)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
y_pred= model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse= mean_squared_error(y_test, y_pred)
mae= mean_absolute_error(y_test, y_pred)
r2= r2_score(y_test, y_pred)

print(mse, mae, r2)
# Out:
# 1661.4641892260538 22.556211494252874 0.7061426079498037

# %%
from sklearn.svm import SVR
model= SVR(kernel= 'rbf',
           epsilon= 0.2)
model.fit(x_train, y_train)
# Out:
# SVR(epsilon=0.2)

# %%
y_pred= model.predict(x_test)
print(model.score(x_train, y_train), model.score(x_test, y_test))
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse= mean_squared_error(y_test, y_pred)
mae= mean_absolute_error(y_test, y_pred)
r2= r2_score(y_test, y_pred)

print(mse, mae, r2)
# Out:
# 0.5019163954331318 0.44770362579207135
# 3215.0056261860327 21.723326305340752 0.44770362579207135
